# %%
import torch
print(torch.__version__)
# Out:
# 1.10.0+cu111

# %%
# !pip install pytorch-pretrained-bert
# Out:
# ...
#      |████████████████████████████████| 123 kB 4.3 MB/s
# ...
#      |████████████████████████████████| 131 kB 28.8 MB/s
# ...
#      |████████████████████████████████| 8.5 MB 55.1 MB/s
# ...
#      |████████████████████████████████| 79 kB 11.2 MB/s
# ...
#      |████████████████████████████████| 138 kB 101.4 MB/s
# ...
#      |████████████████████████████████| 127 kB 101.7 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# ...

# %%
# !pip install allennlp
# Out:
# ...
#      |████████████████████████████████| 738 kB 4.1 MB/s
# ...
#      |████████████████████████████████| 306 kB 60.6 MB/s
# ...
#      |████████████████████████████████| 61 kB 588 kB/s
# ...
#      |████████████████████████████████| 3.1 MB 73.2 MB/s
# ...
#      |████████████████████████████████| 190 kB 77.0 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 124 kB 79.5 MB/s
# ...
#      |████████████████████████████████| 592 kB 77.3 MB/s
# ...
#      |████████████████████████████████| 1.7 MB 55.0 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 73.6 MB/s
# ...
#      |████████████████████████████████| 12.1 MB 24.3 MB/s
# ...
#      |████████████████████████████████| 22.3 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 167 kB 86.8 MB/s
# ...
#      |████████████████████████████████| 59 kB 8.3 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 82.0 MB/s
# ...

# %%
# !pip install pytorch-nlp
# Out:
# ...
#      |████████████████████████████████| 90 kB 3.9 MB/s
# ...

# %%
# !wget https://storage.googleapis.com/bert_models/2018_10_18/uncased_L-12_H-768_A-12.zip
# Out:
# --2021-12-30 23:26:31--  https://storage.googleapis.com/bert_models/2018_10_18/uncased_L-12_H-768_A-12.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.125.128, 142.250.157.128, 64.233.189.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.125.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 407727028 (389M) [application/zip]
# Saving to: ‘uncased_L-12_H-768_A-12.zip’
#
# uncased_L-12_H-768_ 100%[===================>] 388.84M  68.6MB/s    in 6.7s
#
# 2021-12-30 23:26:39 (58.0 MB/s) - ‘uncased_L-12_H-768_A-12.zip’ saved [407727028/407727028]

# %%
# !unzip /content/uncased_L-12_H-768_A-12.zip
# Out:
# Archive:  /content/uncased_L-12_H-768_A-12.zip
#    creating: uncased_L-12_H-768_A-12/
#   inflating: uncased_L-12_H-768_A-12/bert_model.ckpt.meta
#   inflating: uncased_L-12_H-768_A-12/bert_model.ckpt.data-00000-of-00001
#   inflating: uncased_L-12_H-768_A-12/vocab.txt
#   inflating: uncased_L-12_H-768_A-12/bert_model.ckpt.index
#   inflating: uncased_L-12_H-768_A-12/bert_config.json

# %%
# !git clone https://github.com/AtmaHou/FewShotTagging
# Out:
# Cloning into 'FewShotTagging'...
# remote: Enumerating objects: 91, done.
# remote: Counting objects: 100% (91/91), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 91 (delta 44), reused 63 (delta 28), pack-reused 0
# Unpacking objects: 100% (91/91), done.

# %%
# !unzip /content/ACL2020data.zip

# %%
# !unzip /content/xval_myown.zip

# %%
# !rm -r /content/FewShotTagging

# %%
# !pip install --upgrade google-cloud-storage
# Out:
# ...
#      |████████████████████████████████| 106 kB 5.2 MB/s
# ...
#      |████████████████████████████████| 109 kB 13.5 MB/s
# ...
#      |████████████████████████████████| 75 kB 4.6 MB/s
# ...
#   Attempting uninstall: google-api-core
#     Found existing installation: google-api-core 1.26.3
#     Uninstalling google-api-core-1.26.3:
#       Successfully uninstalled google-api-core-1.26.3
#   Attempting uninstall: google-resumable-media
#     Found existing installation: google-resumable-media 0.4.1
#     Uninstalling google-resumable-media-0.4.1:
#       Successfully uninstalled google-resumable-media-0.4.1
#   Attempting uninstall: google-cloud-core
#     Found existing installation: google-cloud-core 1.0.3
#     Uninstalling google-cloud-core-1.0.3:
#       Successfully uninstalled google-cloud-core-1.0.3
#   Attempting uninstall: google-cloud-storage
#     Found existing installation: google-cloud-storage 1.18.1
#     Uninstalling google-cloud-storage-1.18.1:
# ...

# %%
cd ..

# %%
# !source ./scripts/run_L-Tapnet+CDT.sh 0 ner

# %%
# !rm -r /content/ACL2020data/xval_ner/L-Tapnet-CDT.dec_crf.enc_bert.ems_tapnet-dbt.mlp__random_0.5.e_scl_learn0.01_none.lb_sep_scl_fix0.5.t_scl_none1_none.t_i_rand.-mk_tr_.sim_dot.lr_0.00001.up_lr_0.001.bs_4_10.sp_b_2.w_ep_1.ep_1.DATA.ner.shots_1.cross_id_1.m_seed_10151

# %%
f=lambda a,b,c,d:a*b*c*d
print(f(1,2,3,4))  #相当于下面这个函数
def test01(a,b,c,d):
    return a*b*c*d
print(test01(1,2,3,4))


g=[lambda a:a*2,lambda b:b*3]
print(g[0](5))  #调用
print(g[1](6))
# Out:
# 24
# 24
# 10
# 18

# %%
# !source ./scripts/run_L-Tapnet+CDT.sh 0 ner

# %%
# !source ./scripts/run_L-Tapnet+CDT_5.sh 0 ner

# %%
# !rm -r /content/ACL2020dataxval_snips

# %%
# !rm -r /content/result

# %%
# !rm -r /content/FewShotTagging

# %%
cd ..
# Out:
# /content

# %%
# !export BERT_BASE_DIR=/content/uncased_L-12_H-768_A-12/

# !pytorch_pretrained_bert convert_tf_checkpoint_to_pytorch \
  /content/uncased_L-12_H-768_A-12/bert_model.ckpt \
  /content/uncased_L-12_H-768_A-12/bert_config.json \
  /content/uncased_L-12_H-768_A-12/pytorch_model.bin
# Out:
# Building PyTorch model from configuration: {
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "max_position_embeddings": 512,
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "type_vocab_size": 2,
#   "vocab_size": 30522
# }
#
# Converting TensorFlow checkpoint from /content/uncased_L-12_H-768_A-12/bert_model.ckpt
# Loading TF weight bert/embeddings/LayerNorm/beta with shape [768]
# Loading TF weight bert/embeddings/LayerNorm/gamma with shape [768]
# Loading TF weight bert/embeddings/position_embeddings with shape [512, 768]
# Loading TF weight bert/embeddings/token_type_embeddings with shape [2, 768]
# Loading TF weight bert/embeddings/word_embeddings with shape [30522, 768]
# Loading TF weight bert/encoder/layer_0/attention/output/LayerNorm/beta with shape [768]
# ...

# %%
# !mkdir /content/result

# %%
# !rm -r /content/xval_myown/xval_0

# %%
# !rm -r /content/xval_myown/xval_ner

# %%
# !rm -r /content/FewShotTagging/xval_myown

# %%
# !rm -r /content/ACL2020data/xval_ner/L-Tapnet-CDT.dec_crf.enc_bert.ems_tapnet-dbt.mlp__random_0.5.e_scl_learn0.01_none.lb_sep_scl_fix0.5.t_scl_none1_none.t_i_rand.-mk_tr_.sim_dot.lr_0.00001.up_lr_0.001.bs_4_10.sp_b_2.w_ep_1.ep_1.DATA.ner.shots_1.cross_id_1.m_seed_10151

# %%
# !rm /content/xval_myown/xval_ner/ner_train_1.saved.pk
# !rm /content/xval_myown/xval_ner/ner_train_1.json

# %% [markdown]
# tokenizer

# %%
from transformers import BertTokenizer
tz = BertTokenizer.from_pretrained("bert-base-uncased")
tz.convert_tokens_to_ids(["characteristically"])

sent = "Meanwhile"
print(tz.tokenize(sent))


tz.convert_tokens_to_ids(tz.tokenize(sent))
# Out:
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# ['meanwhile']
# [5564]

# %%
path = "/content/xval_myown/xval_ner/ner_test_1.json"

import json

with open(path,'r',encoding='utf-8') as f:
  dictt = json.load(f)
  print(dictt)

# %% [markdown]
# MetaDialog

# %%
# !git clone https://github.com/AtmaHou/MetaDialog
# Out:
# Cloning into 'MetaDialog'...
# remote: Enumerating objects: 134, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 134 (delta 2), reused 1 (delta 0), pack-reused 123
# Receiving objects: 100% (134/134), 119.20 KiB | 1.61 MiB/s, done.
# Resolving deltas: 100% (64/64), done.

# %%
# !unzip /content/snips.zip

# %%
cd ..

# %%
# !git clone https://github.com/AtmaHou/MetaDialog

# %%
# !rm -r /content/FewShotTagging/MetaDialog

# %%
cd /content/MetaDialog
# Out:
# /content/MetaDialog

# %%
# !source ./scripts/run_1_shot_slot_tagging.sh 0 ner
# Out:
# usage: pass gpu id list as param, split with ,
# eg: source run_main.sh 3 snips OR source run_main.sh 3 ner
# log file path ../result/
# [START] set jobs on dataset [ ner ] on gpu [ 0 ]
# [CLI]
# Model: Tapnet-CDT.dec_crf.enc_bert.ems_tapnet.random_1.proto_.lb_sep_scl_fix0.5.trans_learn.t_scl_none1_none.t_i_rand.-mk_tr_.sim_dot.lr_0.00001.up_lr_0.001.bs_4_4.sp_b_2.w_ep_1.ep_4
# Task: ner.shots_1.cross_id_1.m_seed_10150
# [CLI]
# Traceback (most recent call last):
#   File "main.py", line 17, in <module>
#     from utils.trainer import FewShotTrainer, SchemaFewShotTrainer, prepare_optimizer
#   File "/content/MetaDialog/utils/trainer.py", line 18, in <module>
#     from utils.model_helper import make_model, load_model
#   File "/content/MetaDialog/utils/model_helper.py", line 18, in <module>
#     from models.modules.seq_labeler import SequenceLabeler, RuleSequenceLabeler
#   File "/content/MetaDialog/models/modules/seq_labeler.py", line 4, in <module>
# ...

# %%
cd ..
# Out:
# /content

# %%
# !rm -r /content/new_FewShotNLU_data

# %%
# !rm -r /content/uncased_L-12_H-768_A-12

# %%
# !rm -r /content/uncased_L-12_H-768_A-12_1
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory

# %%
# !unzip /content/new_FewShotNLU_data_ACL20.zip

# %%
# !rm -r /content/new_FewShotNLU_data/xval_ner/Tapnet-CDT.dec_crf.enc_bert.ems_tapnet.random_1.proto_.lb_sep_scl_fix0.5.trans_learn.t_scl_none1_none.t_i_rand.-mk_tr_.sim_dot.lr_0.00001.up_lr_0.001.bs_4_20.sp_b_2.w_ep_1.ep_1.DATA.ner.shots_1.cross_id_3.m_seed_10150

# %% [markdown]
# 尝试他们自己写的data的构造方法吧

# %% [markdown]
# 2021.12.26

# %% [markdown]
# 趁我还清醒写一个步骤吧，首先要将所有数据转化为Snips的格式，
#
# 然后自己运行代码生成一个config文件，
#
# 然后运行MetaDialog中的gen_meta_data.sh，生成能够跑的数据结构，但是要注意，support的数据数量要比query中的少，最好就是4和20。
#
# 最后用MetaDialog中的run_1_shot_slot_tagging来跑代码，记得改一下要循环的那些参数
#
# 事实上我只需要构造test数据就可以了

# %%
# !rm -r /content/slot-tagging

# %%
cd ..
# Out:
# /content

# %%
# !unzip /content/slot-tagging.zip
# Out:
# Archive:  /content/slot-tagging.zip
#    creating: slot-tagging/
#    creating: slot-tagging/test/
#   inflating: slot-tagging/test/label
#   inflating: slot-tagging/test/seq.in
#   inflating: slot-tagging/test/seq.out
#    creating: slot-tagging/train/
#   inflating: slot-tagging/train/label
#   inflating: slot-tagging/train/seq.in
#   inflating: slot-tagging/train/seq.out
#    creating: slot-tagging/valid/
#   inflating: slot-tagging/valid/label
#   inflating: slot-tagging/valid/seq.in
#   inflating: slot-tagging/valid/seq.out

# %%
# !git clone https://github.com/AtmaHou/MetaDialog
# Out:
# Cloning into 'MetaDialog'...
# remote: Enumerating objects: 134, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 134 (delta 2), reused 1 (delta 0), pack-reused 123
# Receiving objects: 100% (134/134), 119.20 KiB | 4.97 MiB/s, done.
# Resolving deltas: 100% (64/64), done.

# %%
cd /content/MetaDialog/
# Out:
# /content/MetaDialog

# %% [markdown]
# 记得改输入输出文件路径

# %%
# !rm -r /content/slot-tagging-output/

# %%
# !mkdir /content/slot-tagging-output/

# %%
# !source ./scripts/gen_meta_data.sh atis
# Out:
# usage: pass dataset list as param, split with space
# eg: source gen_mate_data.sh atis
# [START] set jobs on dataset [ atis ]
# [CLI] generate with [ --use_fix_support ]

# %%
# coding: utf-8
import json, os


if __name__ == '__main__':
    # config_dir = "D:/Data/Project/Data/MetaData/config/"
    # all_domain = ['schedule', 'navigate', 'weather']
    config_dir = "/content/config"
    all_domain = ['ITINERARY', 'ACCOMMODATION', 'ATTRACTION', 'FOOD', 'SHOPPING', 'TRANSPORTATION']

    for i in range(len(all_domain)):
        test = all_domain[i]
        dev = all_domain[(i + 1) % len(all_domain)]
        cfg = {'ignore': [], 'dev': dev, 'test': test}
        with open(os.path.join(config_dir, 'config{}.json'.format(i)), 'w') as writer:
            json.dump(cfg, writer)

# %%
cd ..
# Out:
# /

# %%
cd /content/
# Out:
# /content

# %%
# !unzip /content/new_FewShotNLU_data.zip

# %%
cd /content/MetaDialog
# Out:
# /content/MetaDialog

# %% [markdown]
# 注意检查support的数量

# %%
# !source ./scripts/run_5_shot_slot_tagging.sh 0 ner
# Out:
# usage: pass gpu id list as param, split with ,
# eg: source run_main.sh 3 snips OR source run_main.sh 3 ner
# log file path ../result/
# [START] set jobs on dataset [ ner ] on gpu [ 0 ]
# [CLI]
# Model: Tapnet-CDT.dec_crf.enc_bert.ems_tapnet.random_1.proto_.lb_sep_scl_fix0.5.trans_learn.t_scl_none1_none.t_i_rand.-mk_tr_.sim_dot.lr_0.00001.up_lr_0.001.bs_4_4.sp_b_4.w_ep_1.ep_3
# Task: ner.shots_5.cross_id_1.m_seed_10151
# [CLI]
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:1645: FutureWarning: Calling BertTokenizer.from_pretrained() with the path to a single file or url is deprecated and won't be possible anymore in v5. Use a model identifier or the path to a directory instead.
#   FutureWarning,
# Traceback (most recent call last):
#   File "main.py", line 192, in <module>
#     main()
#   File "main.py", line 107, in main
#     test_features, test_label2id, test_id2label = get_testing_data_feature(opt, data_loader, preprocessor)
# ...

# %%
# !rm -r /content/new_FewShotNLU_data/xval_ner_shot_5/Tapnet-CDT.dec_crf.enc_bert.ems_tapnet.random_1.proto_.lb_sep_scl_fix0.5.trans_learn.t_scl_none1_none.t_i_rand.-mk_tr_.sim_dot.lr_0.00001.up_lr_0.001.bs_4_4.sp_b_4.w_ep_1.ep_3.DATA.ner.shots_5.cross_id_1.m_seed_10151
